# %%
import pandas as pd

path = r"C:\Users\Monish\Desktop\PYTHON\data\orders.csv"
df = pd.read_csv(path)
df.head(10)
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 6  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 7  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 8  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 9  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# ...

# %%
df.tail(10)
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 40  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 41  CA-2021-120999  10-09-2021  15-09-2021  Standard Class    LC-16930
# 42  CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 43  CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 44  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 46  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 47  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
#
#      region       product_id         category  sales  quantity  profit
# 40  Central  TEC-PH-10000486       Technology  371.2         4    41.8
# ...

# %%
df.dtypes
# Out:
# order_id        object
# order_date      object
# ship_date       object
# ship_mode       object
# customer_id     object
# region          object
# product_id      object
# category        object
# sales          float64
# quantity         int64
# profit         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     50 non-null     object
#  1   order_date   50 non-null     object
#  2   ship_date    50 non-null     object
#  3   ship_mode    50 non-null     object
#  4   customer_id  50 non-null     object
#  5   region       50 non-null     object
#  6   product_id   50 non-null     object
#  7   category     50 non-null     object
#  8   sales        50 non-null     float64
#  9   quantity     50 non-null     int64
#  10  profit       50 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 4.4+ KB

# %%
df.shape
# Out:
# (50, 11)

# %%
df.describe() # data only for numerical values
# Out:
#              sales   quantity       profit
# count    50.000000  50.000000    50.000000
# mean    300.792000   3.920000   -20.550000
# std     547.564035   1.977836   251.767027
# min       2.500000   2.000000 -1665.100000
# 25%      20.075000   2.000000     2.500000
# 50%      74.650000   3.000000     8.350000
# 75%     249.875000   5.000000    17.650000
# max    3083.400000   9.000000   240.300000

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
#        'region', 'product_id', 'category', 'sales', 'quantity', 'profit'],
#       dtype='object')

# %% [markdown]
# ## change column anme

# %%
df.columns=['order_id', 'order_date', 'shipment_date', 'ship_mode', 'customer_id',
       'region', 'product_id', 'category', 'sales', 'quantity', 'profit']

# %%
df.head()
# Out:
#          order_id  order_date shipment_date       ship_mode customer_id  \
# 0  CA-2020-152156  08-11-2020    11-11-2020    Second Class    CG-12520
# 1  CA-2020-152156  08-11-2020    11-11-2020    Second Class    CG-12520
# 2  CA-2020-138688  12-06-2020    16-06-2020    Second Class    DV-13045
# 3  US-2019-108966  11-10-2019    18-10-2019  Standard Class    SO-20335
# 4  US-2019-108966  11-10-2019    18-10-2019  Standard Class    SO-20335
#
#   region       product_id         category  sales  quantity  profit
# 0  South  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  South  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2   West  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  South  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  South  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %% [markdown]
# ## Read without header

# %%
df=pd.read_csv(path,header=None)
df.head()
# Out:
#                0           1           2               3            4   \
# 0        order_id  order_date   ship_date       ship_mode  customer_id
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 2  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 3  CA-2020-138688  12-06-2020  16-06-2020    Second Class     DV-13045
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335
#
#        5                6                7      8         9       10
# 0  region       product_id         category  sales  quantity  profit
# 1   South  FUR-BO-10001798        Furniture    262         2    41.9
# 2   South  FUR-CH-10000454        Furniture  731.9         3   219.6
# 3    West  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 4   South  FUR-TA-10000577        Furniture  957.6         5    -383

# %%
df.columns=['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
       'region', 'product_id', 'category', 'sales', 'quantity', 'profit']
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode  customer_id  \
# 0        order_id  order_date   ship_date       ship_mode  customer_id
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 2  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 3  CA-2020-138688  12-06-2020  16-06-2020    Second Class     DV-13045
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335
#
#    region       product_id         category  sales  quantity  profit
# 0  region       product_id         category  sales  quantity  profit
# 1   South  FUR-BO-10001798        Furniture    262         2    41.9
# 2   South  FUR-CH-10000454        Furniture  731.9         3   219.6
# 3    West  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 4   South  FUR-TA-10000577        Furniture  957.6         5    -383

# %% [markdown]
# ## Column subset

# %%
new_df=df[["order_id"	,"order_date",	"ship_date"	]]

new_df.head()
# Out:
#          order_id  order_date   ship_date
# 0        order_id  order_date   ship_date
# 1  CA-2020-152156  08-11-2020  11-11-2020
# 2  CA-2020-152156  08-11-2020  11-11-2020
# 3  CA-2020-138688  12-06-2020  16-06-2020
# 4  US-2019-108966  11-10-2019  18-10-2019

# %%
df["order_id"]
# Out:
# 0           order_id
# 1     CA-2020-152156
# 2     CA-2020-152156
# 3     CA-2020-138688
# 4     US-2019-108966
# 5     US-2019-108966
# 6     CA-2018-115812
# 7     CA-2018-115812
# 8     CA-2018-115812
# 9     CA-2018-115812
# 10    CA-2018-115812
# 11    CA-2018-115812
# 12    CA-2018-115812
# 13    CA-2021-114412
# 14    CA-2020-161389
# 15    US-2019-118983
# 16    US-2019-118983
# 17    CA-2018-105893
# 18    CA-2018-167164
# 19    CA-2018-143336
# 20    CA-2018-143336
# 21    CA-2018-143336
# 22    CA-2020-137330
# 23    CA-2020-137330
# 24    US-2021-156909
# 25    CA-2019-106320
# 26    CA-2020-121755
# 27    CA-2020-121755
# 28    US-2019-150630
# 29    US-2019-150630
# 30    US-2019-150630
# 31    US-2019-150630
# 32    US-2019-150630
# 33    US-2019-150630
# 34    US-2019-150630
# 35    CA-2021-107727
# 36    CA-2020-117590
# 37    CA-2020-117590
# 38    CA-2019-117415
# 39    CA-2019-117415
# 40    CA-2019-117415
# 41    CA-2019-117415
# 42    CA-2021-120999
# ...

# %% [markdown]
# ## check data type

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
new_df=df["order_id"]
type(new_df)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## How to select rows

# %%
df.iloc[0:5] #[include,exclude]
# Out:
#          order_id  order_date   ship_date       ship_mode  customer_id  \
# 0        order_id  order_date   ship_date       ship_mode  customer_id
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 2  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 3  CA-2020-138688  12-06-2020  16-06-2020    Second Class     DV-13045
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335
#
#    region       product_id         category  sales  quantity  profit
# 0  region       product_id         category  sales  quantity  profit
# 1   South  FUR-BO-10001798        Furniture    262         2    41.9
# 2   South  FUR-CH-10000454        Furniture  731.9         3   219.6
# 3    West  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 4   South  FUR-TA-10000577        Furniture  957.6         5    -383

# %%
df.iloc[[2,10,4,8]]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 2   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#          product_id         category  sales quantity profit
# 2   FUR-CH-10000454        Furniture  731.9        3  219.6
# 10  OFF-AP-10002892  Office Supplies  114.9        5   34.5
# 4   FUR-TA-10000577        Furniture  957.6        5   -383
# 8   TEC-PH-10002275       Technology  907.2        6   90.7

# %%
df.iloc[[2,10,4,8], 7:9]
# Out:
#            category  sales
# 2         Furniture  731.9
# 10  Office Supplies  114.9
# 4         Furniture  957.6
# 8        Technology  907.2

# %%
df.loc[0:10,["order_id"	,"order_date",	"ship_date"	]]
# Out:
#           order_id  order_date   ship_date
# 0         order_id  order_date   ship_date
# 1   CA-2020-152156  08-11-2020  11-11-2020
# 2   CA-2020-152156  08-11-2020  11-11-2020
# 3   CA-2020-138688  12-06-2020  16-06-2020
# 4   US-2019-108966  11-10-2019  18-10-2019
# 5   US-2019-108966  11-10-2019  18-10-2019
# 6   CA-2018-115812  09-06-2018  14-06-2018
# 7   CA-2018-115812  09-06-2018  14-06-2018
# 8   CA-2018-115812  09-06-2018  14-06-2018
# 9   CA-2018-115812  09-06-2018  14-06-2018
# 10  CA-2018-115812  09-06-2018  14-06-2018

# %%
df.set_index("order_id",inplace=True)

# %%
df
# Out:
#                 order_date   ship_date       ship_mode  customer_id   region  \
# order_id
# order_id        order_date   ship_date       ship_mode  customer_id   region
# CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520    South
# CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520    South
# CA-2020-138688  12-06-2020  16-06-2020    Second Class     DV-13045     West
# US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335    South
# US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335    South
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710     West
# ...

# %%
df.loc["CA-2020-152156"]
# Out:
#                 order_date   ship_date     ship_mode customer_id region  \
# order_id
# CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520  South
# CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520  South
#
#                      product_id   category  sales quantity profit
# order_id
# CA-2020-152156  FUR-BO-10001798  Furniture    262        2   41.9
# CA-2020-152156  FUR-CH-10000454  Furniture  731.9        3  219.6

# %%
df.reset_index(inplace=True)

# %%
df.sort_index(ascending=False,inplace=True)

# %%
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 50  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
# 49  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 47  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 46  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
#
#      region       product_id         category sales quantity profit
# 50  Central  OFF-BI-10004410  Office Supplies  38.2        6     18
# 49     East  TEC-PH-10003988       Technology  21.8        2    6.1
# 48     East  TEC-AC-10002167       Technology    45        3      5
# 47  Central  OFF-ST-10001713  Office Supplies   212        4    8.5
# 46  Central  OFF-BI-10003291  Office Supplies  17.5        2    8.2

# %%
df.sort_index(ascending=True,inplace=True)

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode  customer_id  \
# 0        order_id  order_date   ship_date       ship_mode  customer_id
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 2  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 3  CA-2020-138688  12-06-2020  16-06-2020    Second Class     DV-13045
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335
#
#    region       product_id         category  sales  quantity  profit
# 0  region       product_id         category  sales  quantity  profit
# 1   South  FUR-BO-10001798        Furniture    262         2    41.9
# 2   South  FUR-CH-10000454        Furniture  731.9         3   219.6
# 3    West  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 4   South  FUR-TA-10000577        Furniture  957.6         5    -383

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode  customer_id  \
# 0         order_id  order_date   ship_date       ship_mode  customer_id
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 2   CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 3   CA-2020-138688  12-06-2020  16-06-2020    Second Class     DV-13045
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335
# 5   US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# ...

# %%
df.sort_values('sales', ascending=False,inplace=True)

# %%
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 27  US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 35  CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
# 24  CA-2019-106320  25-09-2019  30-09-2019  Standard Class    EB-13870
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
#
#      region       product_id    category   sales  quantity  profit
# 27     East  FUR-BO-10004834   Furniture  3083.4         7 -1665.1
# 10     West  FUR-TA-10001539   Furniture  1706.2         9    85.3
# 35  Central  TEC-PH-10004977  Technology  1097.5         7   123.5
# 24     West  FUR-TA-10000577   Furniture  1044.6         3   240.3
# 3     South  FUR-TA-10000577   Furniture   957.6         5  -383.0

# %%
df.sort_values(['quantity','profit'],ascending=[True, True])
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 28  US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 23  US-2021-156909  16-07-2021  18-07-2021    Second Class    SF-20065
# 30  US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 18  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 33  US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 42  CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 25  CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 43  CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# ...

# %%
df.reset_index(drop=True)
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 1   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 2   CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
# 3   CA-2019-106320  25-09-2019  30-09-2019  Standard Class    EB-13870
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 8   CA-2018-105893  11-11-2018  18-11-2018  Standard Class    PK-19075
# 9   CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 10  CA-2020-161389  05-12-2020  10-12-2020  Standard Class    IM-15070
# 11  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# ...

# %% [markdown]
# ## filter data in DF
