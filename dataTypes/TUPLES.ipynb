# %% [markdown]
# # Python Tuples

# %%
# A tuple in Python is an immutable and ordered, rest all the things are same as list.
# Tuple items are ordered, unchangeable, and allow duplicate values.
# When we say that tuples are ordered, it means that the items have a defined order, and that order will not change.
# Tuples are unchangeable, meaning that we cannot change, add or remove items after the tuple has been created.

# %%
# To create a tuple with only one item, you have to add a comma after the item, otherwise Python will not recognize it as a string.
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
# Q1.
# Write a Python program to return all the elements as a single tuple, even when the input tuple contains lists inside it.

# Example:

# Input:  test_tuple = ([5, 6], [6, 7, 8, 9], [3])
# Output: (5, 6, 6, 7, 8, 9, 3)


test_tuple = ([5, 6], [6, 7, 8, 9], [3])

tuple1 = ()
for lst in test_tuple:
    tuple1 += tuple(lst)      # concatenate each inner list as tuple

print(tuple1)
print(type(tuple1))
# Out:
# (5, 6, 6, 7, 8, 9, 3)
# <class 'tuple'>

# %%
# Q2.
# Write a Python program to return a tuple containing the element-wise exponentiation of two given tuples.

# Example:

# Input:
# tuple1 = (10, 2, 3, 5)
# tuple2 = (3, 6, 4, 3)

# Output:
# (1000, 64, 81, 125)

tuple1 = (10, 2, 3, 5)
tuple2 = (3, 6, 4, 3)

result_list = []

for a, b in zip(tuple1, tuple2):
    # Calculate a to the power of b
    power = a ** b
    result_list.append(power)

result = tuple(result_list)
print(result)
# Out:
# (1000, 64, 81, 125)

# %%
# Properties of a Python Tuple
# 1. Ordered

# Tuples preserve order.
# Each element has a fixed index.

# t = (10, 20, 30)
# # Index: 0, 1, 2

# 2. Immutable

# Once created, you cannot change a tuple:

# no modifying elements

# no append

# no remove

# t = (1, 2, 3)
# t[0] = 10   #  Error (tuples are immutable)

# 3. Allows Duplicates

# Tuples can store the same value many times.

# t = (1, 1, 2, 3)

# 4. Can Contain Different Data Types (Heterogeneous)

# Tuples can mix types just like lists.

# t = (1, "hello", True, 3.14)

# 5. Can Be Nested

# Tuples can contain lists, sets, or other tuples.

# t = (1, (2, 3), [4, 5])


# Note: inner list is mutable, even if the tuple itself isn’t.

# 6. Indexable and Sliceable

# You can access elements by index or slice.

# t = (10, 20, 30)
# print(t[1])     # 20
# print(t[0:2])   # (10, 20)

# 7. More Memory Efficient Than Lists

# Tuples use less memory and are faster for fixed collections.

# 8. Hashable (If All Elements Are Immutable)

# A tuple can be used as a dictionary key or inside a set if all its elements are hashable.

# t = (1, 2, 3)
# d = {t: "value"}   # ✔ allowed


# But this is invalid:

# (1, [2, 3])  #  not hashable because list is mutable

# 9. Faster Than Lists for Iteration

# Because of immutability and smaller memory usage, they are faster to iterate over.
